# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('image.jpg')
img2 = img.copy()

# img

fig = plt.figure(figsize=(8, 8))

b,g,r = cv2.split(img)
# print(b,g,r)

# b = img.copy()

# print(b)  
fig.add_subplot(2, 4, 1)
plt.imshow(img, cmap='gray')
fig.add_subplot(2, 4, 2)
plt.imshow(b, cmap='gray')
fig.add_subplot(2, 4, 3)
plt.imshow(g, cmap='gray')
fig.add_subplot(2, 4, 4)
plt.imshow(r, cmap='gray')

# print(img.shape)
# x = np.moveaxis(img2, -1, 0)
# print(img2)
img2 = img2[:,:,::-1]
r,g,b = cv2.split(img2)
# print(img2)
# print(x.shape)

fig.add_subplot(2, 4, 5)
plt.imshow(img2, cmap='gray')
fig.add_subplot(2, 4, 6)
plt.imshow(r, cmap='gray')
fig.add_subplot(2, 4, 7)
plt.imshow(g, cmap='gray')
fig.add_subplot(2, 4, 8)
plt.imshow(b, cmap='gray')

# openCV => (H,W,C) 
# (2,4,3)
# [[[
#   1 2 3

# ]]]

# plt.imshow(img, cmap='gray')

# g = img.copy()
# # set blue and red channels to 0
# g[:, :, 0] = 0
# g[:, :, 2] = 0

# %%
p2_img = cv2.imread('image.jpg')
print(p2_img.shape)

p2_img_new = np.moveaxis(p2_img, -1, 0)
print(p2_img_new.shape)
# Out:
# (300, 264, 3)
# (3, 300, 264)

# %%
## open cv = H,W,C
import math 

p3_img = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

print(p3_img.shape)

bit_depth = 4
qlevel = 2**bit_depth
print(qlevel)

# print(p3_img[3])
# 300
for h in range(0,300):
  # 264
  for w in range(0, 264):
    # for c in range(0, 3):
      # print(math.floor(((p3_img[h][w][c]-0)/(255-0))*qlevel))
      # p3_img[h][w][c] = math.floor(((p3_img[h][w][c]-0)/(255-0))*qlevel)
      p3_img[h][w] = math.floor(((p3_img[h][w]-0)/(255-0))*qlevel)

# print(p3_img)
plt.imshow(p3_img, cmap='gray')
# Out:
# (300, 264)
# 16

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator

p4_img = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

print('Original Dimensions : ', p4_img.shape)

scale_percent = 60
width = int(p4_img.shape[1] * scale_percent / 100)
height = int(p4_img.shape[0] * scale_percent / 100)
dim = (width, height)

p4_img = cv2.resize(p4_img, dim)

print('Resized Dimensions : ', p4_img.shape)

# fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax = plt.axes(projection='3d')

# Make data.
y = p4_img[0:p4_img.shape[0]]
x = p4_img[0:p4_img.shape[1]]
# Plot the surface.
X, Y = np.meshgrid(x, y)

ax.plot_surface( X, Y, p4_img,  cmap='gray')

plt.show()

# plt.imshow(p4_img, cmap='gray')
# Out:
# Original Dimensions :  (300, 264)
# Resized Dimensions :  (180, 158)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <module>
#      23 # Plot the surface.
#      24 X, Y = np.meshgrid(x, y)
# ---> 26 ax.plot_surface( X, Y, p4_img[:,:,0],  cmap='gray')
#      28 plt.show()
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap='gray',
                       linewidth=0, antialiased=False)


plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np


img4_org = cv2.imread("./image.jpg", cv2.IMREAD_GRAYSCALE)
print(img4_org.shape)
img4_org = cv2.resize(img4_org, (100,100))
print(img4_org.shape)
X, Y = np.mgrid[0:img4_org.shape[0], 0:img4_org.shape[1]]

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_surface(X, Y, img4_org, rstride=2, cstride=10, cmap='gray', linewidth=10)
# ax.view_init(120, 60)

plt.show()
# Out:
# (300, 264)
# (100, 100)
# /tmp/ipykernel_20866/1737261759.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
